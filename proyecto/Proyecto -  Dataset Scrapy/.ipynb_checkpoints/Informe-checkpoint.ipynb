# %%
path = r"C:\Users\Casa\Desktop\patioTuercaUrl.txt"
urls = []
output = open(path,'r').read()
lista_urls=output.split("\n")
print(type(lista_urls))
print(len(lista_urls))
print(lista_urls[-1])
# Out:
# <class 'list'>
# 247
# https://ecuador.patiotuerca.com/usados/-/autos?orderby=published-at,desc&type_autos_moderated=moderated&page=MjQ2

# %%
path = r"D:\Nicolas\7 SEMESTRE\Github\py-arias-tuqueres-josue-nicolas\proyecto\Proyecto -  Dataset Scrapy\data\patioTuercaUrl.txt"
output = open(path,'r').read()
lista_urls=output.split("\n")
print(type(lista_urls))
print(len(lista_urls))
print(lista_urls[-1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-58feb0086442> in <module>
#       1 path = r"D:\Nicolas\7 SEMESTRE\Github\py-arias-tuqueres-josue-nicolas\proyecto\Proyecto -  Dataset Scrapy\data\patioTuercaUrl.txt"
# ----> 2 output = open(path,'r').read()
#       3 lista_urls=output.split("\n")
#       4 print(type(lista_urls))
#       5 print(len(lista_urls))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Nicolas\\7 SEMESTRE\\Github\\py-arias-tuqueres-josue-nicolas\\proyecto\\Proyecto -  Dataset Scrapy\\data\\patioTuercaUrl.txt'

# %%
path = r"data/datos_vehiculos.txt"
output = open(path,'r')
#print(output)
lista_sucia = list(output)
valores_a_eliminar = [lista_sucia[0],lista_sucia[1]]

print(valor_malo == "\n")


lista_limpia = [item for item in lista_sucia if item not in valores_a_eliminar]
print(len(lista_limpia))
print(lista_limpia)
# Out:
# True
# 16660
# ...
